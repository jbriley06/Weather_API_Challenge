# %%
from citipy import citipy
import json
import random
from random import uniform
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import requests 
import pandas as pd
import openweathermapy.core as ow
import seaborn as sns

# %%
api_key = "4beab9358a73dd949bf0b3d993435364"
settings = {"units": "imperial", "appid": api_key}

# %%
cities_df = pd.DataFrame(columns=("City", "Country", "Lat", "Lng", "Humidity", "Cloudiness", "Date","Max Temp", "Wind Speed"))
cities_df
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Humidity, Cloudiness, Date, Max Temp, Wind Speed]
# Index: []

# %%
#Generate City List
#sample_size_lim = 1500
#sample_size = len(cities_df)
lat = []
lon = []
cities = []


for i in range (540): 
    
    lati = (random.randrange(-90,90,1))
    long = (random.randrange(-180,180,1))
    city = citipy.nearest_city(lati,long)
    city = city.city_name
    index = len(cities)
    lat.append(lat)
    lon.append(long)
    cities.append(city)
    cities_df.set_value(index, "City", city)
    
cities_df.head()
# Out:
#             City Country  Lat  Lng Humidity Cloudiness Date Max Temp  \
# 0  mar del plata     NaN  NaN  NaN      NaN        NaN  NaN      NaN
# 1         kodiak     NaN  NaN  NaN      NaN        NaN  NaN      NaN
# 2       zhigansk     NaN  NaN  NaN      NaN        NaN  NaN      NaN
# 3      jamestown     NaN  NaN  NaN      NaN        NaN  NaN      NaN
# 4         atuona     NaN  NaN  NaN      NaN        NaN  NaN      NaN
#
#   Wind Speed
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
#for index, row in cities_df.iterrows():
#targeturl = url + "appid=" + api_key + "&q=" + trial + "&units=" + units
  #  print(f"Now retrieving weather for #%s city")
   # print(targeturl)
    # counter += 1
    #, %s" % ( counter, cities)
    # % (cities_df["City"]))

# %%
#trial

# %%
#trial = "cities_df['City']"
counter = []
count = 0
 
weather_data = []
#targeturl = url + "appid=" + api_key + "&q=" + trial + "&units=" + units

for city in cities:
    if count < 540:
        try: 
            response = ow.get_current(city, **settings)
            weather_data.append(response)
            count +=1 
            counter.append(count)
        except Exception as e:
            #print(targeturl)
            print(response)
            print(city, ": not found  ", e)
            
            continue
# Out:
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 73.4, 'pressure': 1011, 'humidity': 56, 'temp_min': 73.4, 'temp_max': 73.4}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 180}, 'clouds': {'all': 20}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 4355, 'message': 0.1686, 'country': 'EC', 'sunrise': 1511091733, 'sunset': 1511135492}, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# yuzhno-yeniseyskiy : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -113.58, 'lat': 37.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 57.2, 'pressure': 1025, 'humidity': 15, 'temp_min': 57.2, 'temp_max': 57.2}, 'visibility': 16093, 'wind': {'speed': 2.37, 'deg': 150.505}, 'clouds': {'all': 1}, 'dt': 1511049360, 'sys': {'type': 1, 'id': 2826, 'message': 0.1715, 'country': 'US', 'sunrise': 1511101058, 'sunset': 1511137299}, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# henties bay : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 46.97, 'lat': -25.02}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.6, 'pressure': 1017, 'humidity': 88, 'temp_min': 71.6, 'temp_max': 71.6}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 146.505}, 'clouds': {'all': 75}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 6809, 'message': 0.2027, 'country': 'MG', 'sunrise': 1511056529, 'sunset': 1511104788}, 'id': 1078317, 'name': 'Amparihy', 'cod': 200}
# illoqqortoormiut : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -73.76, 'lat': 42.65}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 42.06, 'pressure': 1000, 'humidity': 81, 'temp_min': 41, 'temp_max': 42.8}, 'visibility': 16093, 'wind': {'speed': 9.17, 'deg': 200}, 'clouds': {'all': 90}, 'dt': 1511051760, 'sys': {'type': 1, 'id': 1292, 'message': 0.1676, 'country': 'US', 'sunrise': 1511092311, 'sunset': 1511126926}, 'id': 5106834, 'name': 'Albany', 'cod': 200}
# nikolskoye : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.98, 'pressure': 1010, 'humidity': 65, 'temp_min': 64.4, 'temp_max': 77}, 'visibility': 16093, 'wind': {'speed': 4.7, 'deg': 60}, 'clouds': {'all': 75}, 'dt': 1511049360, 'sys': {'type': 1, 'id': 818, 'message': 0.0039, 'country': 'US', 'sunrise': 1511109084, 'sunset': 1511149210}, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# illoqqortoormiut : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 55.79, 'pressure': 1035.72, 'humidity': 93, 'temp_min': 55.79, 'temp_max': 55.79, 'sea_level': 1036.77, 'grnd_level': 1035.72}, 'wind': {'speed': 13.56, 'deg': 279.505}, 'clouds': {'all': 8}, 'dt': 1511052837, 'sys': {'message': 0.1637, 'country': 'NZ', 'sunrise': 1511024338, 'sunset': 1511078747}, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# asfi : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -35.46, 'lat': -5.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77.12, 'pressure': 1021.3, 'humidity': 86, 'temp_min': 77.12, 'temp_max': 77.12, 'sea_level': 1025.46, 'grnd_level': 1021.3}, 'wind': {'speed': 10.76, 'deg': 124.505}, 'clouds': {'all': 0}, 'dt': 1511052869, 'sys': {'message': 0.003, 'country': 'BR', 'sunrise': 1511078176, 'sunset': 1511122700}, 'id': 3386213, 'name': 'Touros', 'cod': 200}
# faya : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -156.79, 'lat': 71.29}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.6, 'pressure': 1021, 'humidity': 84, 'temp_min': 8.6, 'temp_max': 8.6}, 'visibility': 16093, 'wind': {'speed': 9.17, 'deg': 130}, 'clouds': {'all': 90}, 'dt': 1511049180, 'sys': {'type': 1, 'id': 26, 'message': 0.1644, 'country': 'US', 'sunrise': 0, 'sunset': 0}, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# nikolskoye : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 149.58, 'lat': -33.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 59.93, 'pressure': 940.89, 'humidity': 83, 'temp_min': 59.93, 'temp_max': 59.93, 'sea_level': 1035.35, 'grnd_level': 940.89}, 'wind': {'speed': 6.17, 'deg': 81.0046}, 'clouds': {'all': 8}, 'dt': 1511052879, 'sys': {'message': 0.2513, 'country': 'AU', 'sunrise': 1511030928, 'sunset': 1511081137}, 'id': 2176632, 'name': 'Bathurst', 'cod': 200}
# grand river south east : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 602, 'main': 'Snow', 'description': 'heavy snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.8, 'pressure': 991, 'humidity': 100, 'temp_min': 33.8, 'temp_max': 33.8}, 'visibility': 1200, 'wind': {'speed': 27.51, 'deg': 270, 'gust': 18}, 'clouds': {'all': 75}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 4754, 'message': 0.1655, 'country': 'AR', 'sunrise': 1511079038, 'sunset': 1511137672}, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# illoqqortoormiut : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 66.6, 'lat': 66.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 15.56, 'pressure': 1020.16, 'humidity': 91, 'temp_min': 15.56, 'temp_max': 15.56, 'sea_level': 1026.59, 'grnd_level': 1020.16}, 'wind': {'speed': 4.94, 'deg': 126.005}, 'clouds': {'all': 88}, 'dt': 1511052883, 'sys': {'message': 0.1649, 'country': 'RU', 'sunrise': 1511066572, 'sunset': 1511085255}, 'id': 1493197, 'name': 'Salekhard', 'cod': 200}
# illoqqortoormiut : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 46.97, 'lat': -25.02}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.6, 'pressure': 1017, 'humidity': 88, 'temp_min': 71.6, 'temp_max': 71.6}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 146.505}, 'clouds': {'all': 75}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 6809, 'message': 0.2027, 'country': 'MG', 'sunrise': 1511056529, 'sunset': 1511104788}, 'id': 1078317, 'name': 'Amparihy', 'cod': 200}
# nikolskoye : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': -3.62, 'pressure': 1020.81, 'humidity': 100, 'temp_min': -3.62, 'temp_max': -3.62, 'sea_level': 1055.9, 'grnd_level': 1020.81}, 'wind': {'speed': 10.76, 'deg': 96.5046}, 'clouds': {'all': 24}, 'dt': 1511052887, 'sys': {'message': 0.0067, 'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# nikolskoye : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 602, 'main': 'Snow', 'description': 'heavy snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.8, 'pressure': 991, 'humidity': 100, 'temp_min': 33.8, 'temp_max': 33.8}, 'visibility': 1200, 'wind': {'speed': 27.51, 'deg': 270, 'gust': 18}, 'clouds': {'all': 75}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 4754, 'message': 0.1655, 'country': 'AR', 'sunrise': 1511079038, 'sunset': 1511137672}, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# illoqqortoormiut : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 147.92, 'lat': 70.63}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 13.85, 'pressure': 1015.54, 'humidity': 80, 'temp_min': 13.85, 'temp_max': 13.85, 'sea_level': 1017.88, 'grnd_level': 1015.54}, 'wind': {'speed': 10.98, 'deg': 351.505}, 'clouds': {'all': 88}, 'dt': 1511052796, 'sys': {'message': 0.1709, 'country': 'RU', 'sunrise': 1511052454, 'sunset': 1511060325}, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# viligili : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -46.3, 'lat': -9.45}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.33, 'pressure': 971.85, 'humidity': 83, 'temp_min': 74.33, 'temp_max': 74.33, 'sea_level': 1022.54, 'grnd_level': 971.85}, 'wind': {'speed': 2.37, 'deg': 250.505}, 'rain': {'3h': 0.5375}, 'clouds': {'all': 48}, 'dt': 1511052927, 'sys': {'message': 0.165, 'country': 'BR', 'sunrise': 1511080407, 'sunset': 1511125676}, 'id': 3394372, 'name': 'Morros', 'cod': 200}
# acapulco : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -17.1, 'lat': 32.67}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.2, 'pressure': 1019, 'humidity': 68, 'temp_min': 66.2, 'temp_max': 66.2}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1511051400, 'sys': {'type': 1, 'id': 5952, 'message': 0.2461, 'country': 'PT', 'sunrise': 1511077324, 'sunset': 1511114718}, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# sataua : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 115.33, 'lat': -33.65}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 61.86, 'pressure': 1026.56, 'humidity': 100, 'temp_min': 61.86, 'temp_max': 61.86, 'sea_level': 1027.61, 'grnd_level': 1026.56}, 'wind': {'speed': 4.5, 'deg': 186.505}, 'clouds': {'all': 64}, 'dt': 1511052885, 'sys': {'message': 0.1721, 'country': 'AU', 'sunrise': 1511039116, 'sunset': 1511089392}, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# tanete : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -50.21, 'lat': -30.18}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.88, 'pressure': 1012.14, 'humidity': 88, 'temp_min': 64.88, 'temp_max': 64.88, 'sea_level': 1022.18, 'grnd_level': 1012.14}, 'wind': {'speed': 5.5, 'deg': 196.005}, 'clouds': {'all': 0}, 'dt': 1511052953, 'sys': {'message': 0.1729, 'country': 'BR', 'sunrise': 1511079264, 'sunset': 1511128712}, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# warqla : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -73.76, 'lat': 42.65}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 42.06, 'pressure': 1000, 'humidity': 81, 'temp_min': 41, 'temp_max': 42.8}, 'visibility': 16093, 'wind': {'speed': 9.17, 'deg': 200}, 'clouds': {'all': 90}, 'dt': 1511051760, 'sys': {'type': 1, 'id': 1292, 'message': 0.1676, 'country': 'US', 'sunrise': 1511092311, 'sunset': 1511126926}, 'id': 5106834, 'name': 'Albany', 'cod': 200}
# karaul : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -57.56, 'lat': -38}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.2, 'pressure': 1004, 'humidity': 81, 'temp_min': 48.2, 'temp_max': 48.2}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1511049600, 'sys': {'type': 1, 'id': 4768, 'message': 0.1664, 'country': 'AR', 'sunrise': 1511079993, 'sunset': 1511131520}, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# moose factory : not found   HTTP Error 404: Not Found
# {'coord': {'lon': -39.25, 'lat': -17.71}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.06, 'pressure': 1026.24, 'humidity': 97, 'temp_min': 78.06, 'temp_max': 78.06, 'sea_level': 1026.19, 'grnd_level': 1026.24}, 'wind': {'speed': 18.25, 'deg': 34.5046}, 'clouds': {'all': 56}, 'dt': 1511052962, 'sys': {'message': 0.1655, 'country': 'BR', 'sunrise': 1511077957, 'sunset': 1511124747}, 'id': 3466980, 'name': 'Caravelas', 'cod': 200}
# pochutla : not found   HTTP Error 404: Not Found
# {'coord': {'lon': 97.2, 'lat': 40.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 18.17, 'pressure': 858.29, 'humidity': 80, 'temp_min': 18.17, 'temp_max': 18.17, 'sea_level': 1051.76, 'grnd_level': 858.29}, 'wind': {'speed': 6.96, 'deg': 248.505}, 'clouds': {'all': 0}, 'dt': 1511052983, 'sys': {'message': 0.1637, 'country': 'CN', 'sunrise': 1511050882, 'sunset': 1511086282}, 'id': 1528998, 'name': 'Yumen', 'cod': 200}
# taburi : not found   HTTP Error 404: Not Found

# %%
print(len(weather_data))
# Out:
# 457

# %%
weather_data
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -38, 'lon': -57.56},
#   'dt': 1511049600,
#   'id': 3430863,
#   'main': {'humidity': 81,
#    'pressure': 1004,
#    'temp': 48.2,
#    'temp_max': 48.2,
#    'temp_min': 48.2},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#    'id': 4768,
#    'message': 0.1664,
#    'sunrise': 1511079993,
#    'sunset': 1511131520,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 360, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 57.79, 'lon': -152.41},
#   'dt': 1511049180,
#   'id': 5866583,
#   'main': {'humidity': 59,
#    'pressure': 1013,
#    'temp': 37.4,
#    'temp_max': 37.4,
#    'temp_min': 37.4},
#   'name': 'Kodiak',
#   'sys': {'country': 'US',
#    'id': 101,
#    'message': 0.1655,
#    'sunrise': 1511114705,
#    'sunset': 1511142276,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 66.77, 'lon': 123.37},
#   'dt': 1511052831,
#   'id': 2012530,
#   'main': {'grnd_level': 1027.62,
#    'humidity': 76,
#    'pressure': 1027.62,
#    'sea_level': 1036.97,
#    'temp': -17.3,
#    'temp_max': -17.3,
#    'temp_min': -17.3},
#   'name': 'Zhigansk',
#   'sys': {'country': 'RU',
#    'message': 0.1651,
#    'sunrise': 1511053108,
#    'sunset': 1511071464},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 147.505, 'speed': 5.95}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1511051280,
#   'id': 5122534,
#   'main': {'humidity': 93,
#    'pressure': 990,
#    'temp': 48.24,
#    'temp_max': 51.8,
#    'temp_min': 44.6},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#    'id': 2111,
#    'message': 0.1667,
#    'sunrise': 1511093539,
#    'sunset': 1511128328,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'moderate rain',
#     'icon': '10n',
#     'id': 501,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 180, 'gust': 8.7, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1511052831,
#   'id': 4020109,
#   'main': {'grnd_level': 1022.43,
#    'humidity': 100,
#    'pressure': 1022.43,
#    'sea_level': 1022.54,
#    'temp': 79.46,
#    'temp_max': 79.46,
#    'temp_min': 79.46},
#   'name': 'Atuona',
#   'rain': {'3h': 0.105},
#   'sys': {'country': 'PF',
#    'message': 0.1677,
#    'sunrise': 1511102632,
#    'sunset': 1511147969},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 83.0046, 'speed': 11.32}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -33.9, 'lon': 148.17},
#   'dt': 1511052832,
#   'id': 2164457,
#   'main': {'grnd_level': 991.79,
#    'humidity': 91,
#    'pressure': 991.79,
#    'sea_level': 1035.19,
#    'temp': 66.95,
#    'temp_max': 66.95,
#    'temp_min': 66.95},
#   'name': 'Grenfell',
#   'sys': {'country': 'AU',
#    'message': 0.1647,
#    'sunrise': 1511031205,
#    'sunset': 1511081538},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5046, 'speed': 11.77}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 67.47, 'lon': 78.7},
#   'dt': 1511052832,
#   'id': 1489853,
#   'main': {'grnd_level': 1026,
#    'humidity': 75,
#    'pressure': 1026,
#    'sea_level': 1029.8,
#    'temp': 0.26,
#    'temp_max': 0.26,
#    'temp_min': 0.26},
#   'name': 'Tazovskiy',
#   'sys': {'country': 'RU',
#    'message': 0.006,
#    'sunrise': 1511064491,
#    'sunset': 1511081526},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 54.5046, 'speed': 7.4}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 69.75, 'lon': 61.65},
#   'dt': 1511052833,
#   'id': 1544819,
#   'main': {'grnd_level': 1011.25,
#    'humidity': 91,
#    'pressure': 1011.25,
#    'sea_level': 1023.76,
#    'temp': 10.92,
#    'temp_max': 10.92,
#    'temp_min': 10.92},
#   'name': 'Rudnik',
#   'sys': {'country': 'RU',
#    'message': 0.0047,
#    'sunrise': 1511071452,
#    'sunset': 1511082745},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 123.505, 'speed': 8.08}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.88, 'lon': 147.33},
#   'dt': 1511049600,
#   'id': 2163355,
#   'main': {'humidity': 33,
#    'pressure': 1023,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#    'id': 8195,
#    'message': 0.0047,
#    'sunrise': 1511030067,
#    'sunset': 1511083092,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 310, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1511052834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.73,
#    'humidity': 100,
#    'pressure': 1029.73,
#    'sea_level': 1029.88,
#    'temp': 73.43,
#    'temp_max': 73.43,
#    'temp_min': 73.43},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.1676,
#    'sunrise': 1511100387,
#    'sunset': 1511148273},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 144.005, 'speed': 17.47}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -32.5, 'lon': 137.77},
#   'dt': 1511049600,
#   'id': 2063056,
#   'main': {'humidity': 56,
#    'pressure': 1014,
#    'temp': 73.4,
#    'temp_max': 73.4,
#    'temp_min': 73.4},
#   'name': 'Port Augusta',
#   'sys': {'country': 'AU',
#    'id': 8241,
#    'message': 0.1681,
#    'sunrise': 1511033878,
#    'sunset': 1511083855,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 170, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 68.75, 'lon': 161.3},
#   'dt': 1511052835,
#   'id': 2126199,
#   'main': {'grnd_level': 1006.47,
#    'humidity': 79,
#    'pressure': 1006.47,
#    'sea_level': 1014.8,
#    'temp': 6.56,
#    'temp_max': 6.56,
#    'temp_min': 6.56},
#   'name': 'Cherskiy',
#   'sys': {'country': 'RU',
#    'message': 0.0063,
#    'sunrise': 1511045987,
#    'sunset': 1511060372},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 230.505, 'speed': 9.64}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.67, 'lon': 92.75},
#   'dt': 1511052835,
#   'id': 1259385,
#   'main': {'grnd_level': 1022.84,
#    'humidity': 100,
#    'pressure': 1022.84,
#    'sea_level': 1023.11,
#    'temp': 83.6,
#    'temp_max': 83.6,
#    'temp_min': 83.6},
#   'name': 'Port Blair',
#   'sys': {'country': 'IN',
#    'message': 0.1633,
#    'sunrise': 1511048845,
#    'sunset': 1511090471},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 38.0046, 'speed': 2.26}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.5, 'lon': 77.68},
#   'dt': 1511052667,
#   'id': 1263364,
#   'main': {'grnd_level': 1006.87,
#    'humidity': 76,
#    'pressure': 1006.87,
#    'sea_level': 1029.07,
#    'temp': 59.34,
#    'temp_max': 59.34,
#    'temp_min': 59.34},
#   'name': 'Mathura',
#   'sys': {'country': 'IN',
#    'message': 0.1648,
#    'sunrise': 1511053978,
#    'sunset': 1511092565},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 323.505, 'speed': 9.98}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -17.62, 'lon': 27.34},
#   'dt': 1511052836,
#   'id': 895057,
#   'main': {'grnd_level': 961.72,
#    'humidity': 87,
#    'pressure': 961.72,
#    'sea_level': 1026.11,
#    'temp': 72.44,
#    'temp_max': 72.44,
#    'temp_min': 72.44},
#   'name': 'Binga',
#   'sys': {'country': 'ZW',
#    'message': 0.1652,
#    'sunrise': 1511061985,
#    'sunset': 1511108750},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 97.0046, 'speed': 6.96}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -38.55, 'lon': -58.74},
#   'dt': 1511052808,
#   'id': 3430443,
#   'main': {'grnd_level': 1011.82,
#    'humidity': 75,
#    'pressure': 1011.82,
#    'sea_level': 1017.48,
#    'temp': 52.1,
#    'temp_max': 52.1,
#    'temp_min': 52.1},
#   'name': 'Necochea',
#   'sys': {'country': 'AR',
#    'message': 0.1668,
#    'sunrise': 1511080195,
#    'sunset': 1511131886},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 324.505, 'speed': 7.18}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.6, 'lon': 168.33},
#   'dt': 1511052837,
#   'id': 2206939,
#   'main': {'grnd_level': 1035.72,
#    'humidity': 93,
#    'pressure': 1035.72,
#    'sea_level': 1036.77,
#    'temp': 55.79,
#    'temp_max': 55.79,
#    'temp_min': 55.79},
#   'name': 'Bluff',
#   'sys': {'country': 'NZ',
#    'message': 0.1637,
#    'sunrise': 1511024338,
#    'sunset': 1511078747},
#   'weather': [{'description': 'clear sky',
#     'icon': '02d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 279.505, 'speed': 13.56}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -24.87, 'lon': 113.63},
#   'dt': 1511052837,
#   'id': 2074865,
#   'main': {'grnd_level': 1025.19,
#    'humidity': 99,
#    'pressure': 1025.19,
#    'sea_level': 1026.47,
#    'temp': 68.93,
#    'temp_max': 68.93,
#    'temp_min': 68.93},
#   'name': 'Carnarvon',
#   'sys': {'country': 'AU',
#    'message': 0.1675,
#    'sunrise': 1511040549,
#    'sunset': 1511088766},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 131.005, 'speed': 11.65}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1511051760,
#   'id': 5848280,
#   'main': {'humidity': 94,
#    'pressure': 1012,
#    'temp': 70.25,
#    'temp_max': 71.6,
#    'temp_min': 68},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#    'id': 833,
#    'message': 0.1671,
#    'sunrise': 1511110329,
#    'sunset': 1511149996,
#    'type': 1},
#   'visibility': 6437,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 260, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -20.34, 'lon': 57.76},
#   'dt': 1511052839,
#   'id': 1106677,
#   'main': {'grnd_level': 1016.84,
#    'humidity': 92,
#    'pressure': 1016.84,
#    'sea_level': 1028.5,
#    'temp': 74.15,
#    'temp_max': 74.15,
#    'temp_min': 74.15},
#   'name': 'Bambous Virieux',
#   'sys': {'country': 'MU',
#    'message': 0.166,
#    'sunrise': 1511054421,
#    'sunset': 1511101712},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 101.005, 'speed': 6.62}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.92, 'lon': 25.57},
#   'dt': 1511049600,
#   'id': 964420,
#   'main': {'humidity': 82,
#    'pressure': 1015,
#    'temp': 57.2,
#    'temp_max': 57.2,
#    'temp_min': 57.2},
#   'name': 'Port Elizabeth',
#   'sys': {'country': 'ZA',
#    'id': 6596,
#    'message': 0.1645,
#    'sunrise': 1511060616,
#    'sunset': 1511110984,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 290, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 2.27, 'lon': -75.8},
#   'dt': 1511052839,
#   'id': 3672123,
#   'main': {'grnd_level': 878.31,
#    'humidity': 81,
#    'pressure': 878.31,
#    'sea_level': 1018.33,
#    'temp': 68.3,
#    'temp_max': 68.3,
#    'temp_min': 68.3},
#   'name': 'Pital',
#   'sys': {'country': 'CO',
#    'message': 0.1635,
#    'sunrise': 1511088498,
#    'sunset': 1511131741},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 17.0046, 'speed': 2.37}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1511051760,
#   'id': 5848280,
#   'main': {'humidity': 94,
#    'pressure': 1012,
#    'temp': 70.25,
#    'temp_max': 71.6,
#    'temp_min': 68},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#    'id': 833,
#    'message': 0.1671,
#    'sunrise': 1511110329,
#    'sunset': 1511149996,
#    'type': 1},
#   'visibility': 6437,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 260, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 56.12, 'lon': 101.16},
#   'dt': 1511049600,
#   'id': 2013399,
#   'main': {'humidity': 92,
#    'pressure': 1019,
#    'temp': 21.2,
#    'temp_max': 21.2,
#    'temp_min': 21.2},
#   'name': 'Vikhorevka',
#   'sys': {'country': 'RU',
#    'id': 7253,
#    'message': 0.1657,
#    'sunrise': 1511053220,
#    'sunset': 1511082029,
#    'type': 1},
#   'visibility': 6000,
#   'weather': [{'description': 'light shower snow',
#     'icon': '13n',
#     'id': 620,
#     'main': 'Snow'}],
#   'wind': {'deg': 110, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 46.7, 'lon': -75.45},
#   'dt': 1511052841,
#   'id': 5952330,
#   'main': {'grnd_level': 977.61,
#    'humidity': 89,
#    'pressure': 977.61,
#    'sea_level': 1014.92,
#    'temp': 26.67,
#    'temp_max': 26.67,
#    'temp_min': 26.67},
#   'name': 'Ferme-Neuve',
#   'sys': {'country': 'CA',
#    'message': 0.1653,
#    'sunrise': 1511093421,
#    'sunset': 1511126624},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 101.005, 'speed': 4.61}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 6.3, 'lon': -10.8},
#   'dt': 1511051400,
#   'id': 2274895,
#   'main': {'humidity': 94,
#    'pressure': 1011,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Monrovia',
#   'sys': {'country': 'LR',
#    'id': 6130,
#    'message': 0.1693,
#    'sunrise': 1511073239,
#    'sunset': 1511115793,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 225.505, 'speed': 7.74}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -6.09, 'lon': -35.21},
#   'dt': 1511049600,
#   'id': 3393922,
#   'main': {'humidity': 78,
#    'pressure': 1011,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Nisia Floresta',
#   'sys': {'country': 'BR',
#    'id': 4546,
#    'message': 0.2265,
#    'sunrise': 1511078039,
#    'sunset': 1511122718,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -20.33, 'lon': -40.29},
#   'dt': 1511049600,
#   'id': 3445026,
#   'main': {'humidity': 78,
#    'pressure': 1010,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Vila Velha',
#   'sys': {'country': 'BR',
#    'id': 4601,
#    'message': 0.1654,
#    'sunrise': 1511077951,
#    'sunset': 1511125254,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 10, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 71.97, 'lon': 102.5},
#   'dt': 1511052843,
#   'id': 2022572,
#   'main': {'grnd_level': 1033.21,
#    'humidity': 55,
#    'pressure': 1033.21,
#    'sea_level': 1038.47,
#    'temp': -10.68,
#    'temp_max': -10.68,
#    'temp_min': -10.68},
#   'name': 'Khatanga',
#   'sys': {'country': 'RU', 'message': 0.167, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 71.5046, 'speed': 13.22}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1511049600,
#   'id': 1015776,
#   'main': {'humidity': 87,
#    'pressure': 1015,
#    'temp': 55.4,
#    'temp_max': 55.4,
#    'temp_min': 55.4},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#    'id': 6591,
#    'message': 0.1713,
#    'sunrise': 1511061862,
#    'sunset': 1511112393,
#    'type': 1},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 40, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 60.75, 'lon': 72.86},
#   'dt': 1511052773,
#   'id': 6696686,
#   'main': {'grnd_level': 1021.38,
#    'humidity': 87,
#    'pressure': 1021.38,
#    'sea_level': 1030.16,
#    'temp': 17.94,
#    'temp_max': 17.94,
#    'temp_min': 17.94},
#   'name': 'Pyt-Yakh',
#   'sys': {'country': 'RU',
#    'message': 0.1656,
#    'sunrise': 1511061689,
#    'sunset': 1511087142},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 271.005, 'speed': 6.73}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -0.95, 'lon': -80.73},
#   'dt': 1511049600,
#   'id': 3654410,
#   'main': {'humidity': 83,
#    'pressure': 1010,
#    'temp': 73.4,
#    'temp_max': 73.4,
#    'temp_min': 73.4},
#   'name': 'Manta',
#   'sys': {'country': 'EC',
#    'id': 4364,
#    'message': 0.1674,
#    'sunrise': 1511089406,
#    'sunset': 1511133201,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 230, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1511052834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.73,
#    'humidity': 100,
#    'pressure': 1029.73,
#    'sea_level': 1029.88,
#    'temp': 73.43,
#    'temp_max': 73.43,
#    'temp_min': 73.43},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.1676,
#    'sunrise': 1511100387,
#    'sunset': 1511148273},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 144.005, 'speed': 17.47}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.15, 'lon': 57.08},
#   'dt': 1511052845,
#   'id': 123941,
#   'main': {'grnd_level': 1024.46,
#    'humidity': 66,
#    'pressure': 1024.46,
#    'sea_level': 1032.63,
#    'temp': 61.37,
#    'temp_max': 61.37,
#    'temp_min': 61.37},
#   'name': 'Minab',
#   'sys': {'country': 'IR',
#    'message': 0.1676,
#    'sunrise': 1511058887,
#    'sunset': 1511097546},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 48.0046, 'speed': 5.84}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 16.47, 'lon': 107.6},
#   'dt': 1511049600,
#   'id': 1580240,
#   'main': {'humidity': 100,
#    'pressure': 1012,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Hue',
#   'sys': {'country': 'VN',
#    'id': 7982,
#    'message': 0.1647,
#    'sunrise': 1511045709,
#    'sunset': 1511086476,
#    'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 110, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 39.01, 'lon': -77.43},
#   'dt': 1511051160,
#   'id': 4787534,
#   'main': {'humidity': 62,
#    'pressure': 999,
#    'temp': 56.16,
#    'temp_max': 62.6,
#    'temp_min': 42.8},
#   'name': 'Sterling',
#   'sys': {'country': 'US',
#    'id': 2856,
#    'message': 0.1655,
#    'sunrise': 1511092641,
#    'sunset': 1511128360,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'mist',
#     'icon': '50n',
#     'id': 701,
#     'main': 'Mist'}],
#   'wind': {'deg': 200, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.08},
#   'dt': 1511052846,
#   'id': 1282256,
#   'main': {'grnd_level': 1022.02,
#    'humidity': 100,
#    'pressure': 1022.02,
#    'sea_level': 1022.1,
#    'temp': 82.79,
#    'temp_max': 82.79,
#    'temp_min': 82.79},
#   'name': 'Hithadhoo',
#   'rain': {'3h': 0.5625},
#   'sys': {'country': 'MV',
#    'message': 0.1734,
#    'sunrise': 1511052516,
#    'sunset': 1511096250},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 316.505, 'speed': 10.76}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': -16.44, 'lon': -51.12},
#   'dt': 1511052636,
#   'id': 3461090,
#   'main': {'grnd_level': 964.8,
#    'humidity': 76,
#    'pressure': 964.8,
#    'sea_level': 1022.38,
#    'temp': 76.44,
#    'temp_max': 76.44,
#    'temp_min': 76.44},
#   'name': 'Ipora',
#   'sys': {'country': 'BR',
#    'message': 0.1649,
#    'sunrise': 1511080927,
#    'sunset': 1511127475},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 301.005, 'speed': 5.06}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1511052847,
#   'id': 964432,
#   'main': {'grnd_level': 1020,
#    'humidity': 99,
#    'pressure': 1020,
#    'sea_level': 1028.99,
#    'temp': 58.49,
#    'temp_max': 58.49,
#    'temp_min': 58.49},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA',
#    'message': 0.1657,
#    'sunrise': 1511060342,
#    'sunset': 1511110624},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 326.005, 'speed': 5.84}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 57.05, 'lon': -135.33},
#   'dt': 1511049360,
#   'id': 5557293,
#   'main': {'humidity': 74,
#    'pressure': 1003,
#    'temp': 32.09,
#    'temp_max': 37.4,
#    'temp_min': 28.4},
#   'name': 'Sitka',
#   'sys': {'country': 'US',
#    'id': 160,
#    'message': 0.2482,
#    'sunrise': 1511110352,
#    'sunset': 1511138431,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light snow',
#     'icon': '13d',
#     'id': 600,
#     'main': 'Snow'},
#    {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 320, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 27.98, 'lon': -114.06},
#   'dt': 1511052848,
#   'id': 4021858,
#   'main': {'grnd_level': 1015.7,
#    'humidity': 51,
#    'pressure': 1015.7,
#    'sea_level': 1027.12,
#    'temp': 80,
#    'temp_max': 80,
#    'temp_min': 80},
#   'name': 'Guerrero Negro',
#   'sys': {'country': 'MX',
#    'message': 0.1688,
#    'sunrise': 1511100072,
#    'sunset': 1511138521},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 303.005, 'speed': 2.71}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -0.74, 'lon': -90.35},
#   'dt': 1511049600,
#   'id': 3652764,
#   'main': {'humidity': 56,
#    'pressure': 1011,
#    'temp': 73.4,
#    'temp_max': 73.4,
#    'temp_min': 73.4},
#   'name': 'Puerto Ayora',
#   'sys': {'country': 'EC',
#    'id': 4355,
#    'message': 0.1686,
#    'sunrise': 1511091733,
#    'sunset': 1511135492,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1511052849,
#   'id': 3874787,
#   'main': {'grnd_level': 1000.14,
#    'humidity': 100,
#    'pressure': 1000.14,
#    'sea_level': 1013.5,
#    'temp': 39.95,
#    'temp_max': 39.95,
#    'temp_min': 39.95},
#   'name': 'Punta Arenas',
#   'rain': {'3h': 0.17},
#   'sys': {'country': 'CL',
#    'message': 0.1679,
#    'sunrise': 1511080156,
#    'sunset': 1511137805},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 220.505, 'speed': 34.69}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1511049600,
#   'id': 4035715,
#   'main': {'humidity': 74,
#    'pressure': 1014,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#    'id': 8340,
#    'message': 0.3267,
#    'sunrise': 1511106537,
#    'sunset': 1511154033,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1511049600,
#   'id': 1015776,
#   'main': {'humidity': 87,
#    'pressure': 1015,
#    'temp': 55.4,
#    'temp_max': 55.4,
#    'temp_min': 55.4},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#    'id': 6591,
#    'message': 0.1713,
#    'sunrise': 1511061862,
#    'sunset': 1511112393,
#    'type': 1},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 40, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 48.43, 'lon': -123.37},
#   'dt': 1511050500,
#   'id': 6174041,
#   'main': {'humidity': 70,
#    'pressure': 1020,
#    'temp': 48.81,
#    'temp_max': 51.8,
#    'temp_min': 46.4},
#   'name': 'Victoria',
#   'sys': {'country': 'CA',
#    'id': 3364,
#    'message': 0.1673,
#    'sunrise': 1511105271,
#    'sunset': 1511137778,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 51.97, 'lon': 59.9},
#   'dt': 1511052852,
#   'id': 542133,
#   'main': {'grnd_level': 999.74,
#    'humidity': 90,
#    'pressure': 999.74,
#    'sea_level': 1043.94,
#    'temp': 29.46,
#    'temp_max': 29.46,
#    'temp_min': 29.46},
#   'name': 'Krasnoyarskiy',
#   'sys': {'country': 'RU',
#    'message': 0.1675,
#    'sunrise': 1511062018,
#    'sunset': 1511093044},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 261.505, 'speed': 12.88}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 13.59, 'lon': 102.97},
#   'dt': 1511052852,
#   'id': 1822207,
#   'main': {'grnd_level': 1019.11,
#    'humidity': 97,
#    'pressure': 1019.11,
#    'sea_level': 1022.91,
#    'temp': 74.91,
#    'temp_max': 74.91,
#    'temp_min': 74.91},
#   'name': 'Sisophon',
#   'rain': {'3h': 3.945},
#   'sys': {'country': 'KH',
#    'message': 0.1777,
#    'sunrise': 1511046561,
#    'sunset': 1511087848},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10d',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 36.0046, 'speed': 7.63}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 60.75, 'lon': 72.86},
#   'dt': 1511052773,
#   'id': 6696686,
#   'main': {'grnd_level': 1021.38,
#    'humidity': 87,
#    'pressure': 1021.38,
#    'sea_level': 1030.16,
#    'temp': 17.94,
#    'temp_max': 17.94,
#    'temp_min': 17.94},
#   'name': 'Pyt-Yakh',
#   'sys': {'country': 'RU',
#    'message': 0.1656,
#    'sunrise': 1511061689,
#    'sunset': 1511087142},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 271.005, 'speed': 6.73}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.6, 'lon': 168.33},
#   'dt': 1511052837,
#   'id': 2206939,
#   'main': {'grnd_level': 1035.72,
#    'humidity': 93,
#    'pressure': 1035.72,
#    'sea_level': 1036.77,
#    'temp': 55.79,
#    'temp_max': 55.79,
#    'temp_min': 55.79},
#   'name': 'Bluff',
#   'sys': {'country': 'NZ',
#    'message': 0.1637,
#    'sunrise': 1511024338,
#    'sunset': 1511078747},
#   'weather': [{'description': 'clear sky',
#     'icon': '02d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 279.505, 'speed': 13.56}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 37.05, 'lon': 140.88},
#   'dt': 1511049600,
#   'id': 2112539,
#   'main': {'humidity': 48,
#    'pressure': 1011,
#    'temp': 39.2,
#    'temp_max': 39.2,
#    'temp_min': 39.2},
#   'name': 'Iwaki',
#   'sys': {'country': 'JP',
#    'id': 7594,
#    'message': 0.1649,
#    'sunrise': 1511039937,
#    'sunset': 1511076259,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 310, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 47.67, 'lon': -52.73},
#   'dt': 1511049600,
#   'id': 6167817,
#   'main': {'humidity': 93,
#    'pressure': 994,
#    'temp': 41,
#    'temp_max': 41,
#    'temp_min': 41},
#   'name': 'Torbay',
#   'sys': {'country': 'CA',
#    'id': 3467,
#    'message': 0.1643,
#    'sunrise': 1511088149,
#    'sunset': 1511120988,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 310, 'gust': 8.7, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -21.64, 'lon': -41.05},
#   'dt': 1511052854,
#   'id': 3448903,
#   'main': {'grnd_level': 1023.81,
#    'humidity': 97,
#    'pressure': 1023.81,
#    'sea_level': 1023.96,
#    'temp': 76.85,
#    'temp_max': 76.85,
#    'temp_min': 76.85},
#   'name': 'Sao Joao da Barra',
#   'sys': {'country': 'BR',
#    'message': 0.0045,
#    'sunrise': 1511078002,
#    'sunset': 1511125569},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 43.0046, 'speed': 29.66}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1511049600,
#   'id': 4035715,
#   'main': {'humidity': 74,
#    'pressure': 1014,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#    'id': 8340,
#    'message': 0.3267,
#    'sunrise': 1511106537,
#    'sunset': 1511154033,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 52.1, 'lon': -9.78},
#   'dt': 1511052855,
#   'id': 2963311,
#   'main': {'grnd_level': 1019.92,
#    'humidity': 100,
#    'pressure': 1019.92,
#    'sea_level': 1036.93,
#    'temp': 48.86,
#    'temp_max': 48.86,
#    'temp_min': 48.86},
#   'name': 'Killorglin',
#   'rain': {'3h': 0.57},
#   'sys': {'country': 'IE',
#    'message': 0.0096,
#    'sunrise': 1511078792,
#    'sunset': 1511109721},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 133.505, 'speed': 0.69}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1511052855,
#   'id': 3366880,
#   'main': {'grnd_level': 988.71,
#    'humidity': 96,
#    'pressure': 988.71,
#    'sea_level': 1028.74,
#    'temp': 46.34,
#    'temp_max': 46.34,
#    'temp_min': 46.34},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#    'message': 0.168,
#    'sunrise': 1511062071,
#    'sunset': 1511112573},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 311.005, 'speed': 2.59}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -38, 'lon': -57.56},
#   'dt': 1511049600,
#   'id': 3430863,
#   'main': {'humidity': 81,
#    'pressure': 1004,
#    'temp': 48.2,
#    'temp_max': 48.2,
#    'temp_min': 48.2},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#    'id': 4768,
#    'message': 0.1664,
#    'sunrise': 1511079993,
#    'sunset': 1511131520,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 360, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -25.02, 'lon': 46.97},
#   'dt': 1511049600,
#   'id': 1078317,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 71.6,
#    'temp_max': 71.6,
#    'temp_min': 71.6},
#   'name': 'Amparihy',
#   'sys': {'country': 'MG',
#    'id': 6809,
#    'message': 0.2027,
#    'sunrise': 1511056529,
#    'sunset': 1511104788,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 146.505, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 37.1, 'lon': -113.58},
#   'dt': 1511049360,
#   'id': 5546220,
#   'main': {'humidity': 15,
#    'pressure': 1025,
#    'temp': 57.2,
#    'temp_max': 57.2,
#    'temp_min': 57.2},
#   'name': 'Saint George',
#   'sys': {'country': 'US',
#    'id': 2826,
#    'message': 0.1715,
#    'sunrise': 1511101058,
#    'sunset': 1511137299,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 150.505, 'speed': 2.37}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': -16.48, 'lon': -151.75},
#   'dt': 1511052858,
#   'id': 4034551,
#   'main': {'grnd_level': 1024.46,
#    'humidity': 100,
#    'pressure': 1024.46,
#    'sea_level': 1024.49,
#    'temp': 79.46,
#    'temp_max': 79.46,
#    'temp_min': 79.46},
#   'name': 'Faanui',
#   'sys': {'country': 'PF',
#    'message': 0.165,
#    'sunrise': 1511105073,
#    'sunset': 1511151639},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 93.0046, 'speed': 21.83}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1511052834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.73,
#    'humidity': 100,
#    'pressure': 1029.73,
#    'sea_level': 1029.88,
#    'temp': 73.43,
#    'temp_max': 73.43,
#    'temp_min': 73.43},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.1676,
#    'sunrise': 1511100387,
#    'sunset': 1511148273},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 144.005, 'speed': 17.47}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 22.89, 'lon': -109.91},
#   'dt': 1511049300,
#   'id': 3985710,
#   'main': {'humidity': 35,
#    'pressure': 1014,
#    'temp': 85.19,
#    'temp_max': 86,
#    'temp_min': 84.2},
#   'name': 'Cabo San Lucas',
#   'sys': {'country': 'MX',
#    'id': 4016,
#    'message': 0.1644,
#    'sunrise': 1511098545,
#    'sunset': 1511138058,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '02d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 110, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1511052849,
#   'id': 3874787,
#   'main': {'grnd_level': 1000.14,
#    'humidity': 100,
#    'pressure': 1000.14,
#    'sea_level': 1013.5,
#    'temp': 39.95,
#    'temp_max': 39.95,
#    'temp_min': 39.95},
#   'name': 'Punta Arenas',
#   'rain': {'3h': 0.17},
#   'sys': {'country': 'CL',
#    'message': 0.1679,
#    'sunrise': 1511080156,
#    'sunset': 1511137805},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 220.505, 'speed': 34.69}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -25.02, 'lon': 46.97},
#   'dt': 1511049600,
#   'id': 1078317,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 71.6,
#    'temp_max': 71.6,
#    'temp_min': 71.6},
#   'name': 'Amparihy',
#   'sys': {'country': 'MG',
#    'id': 6809,
#    'message': 0.2027,
#    'sunrise': 1511056529,
#    'sunset': 1511104788,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 146.505, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 65.28, 'lon': -126.83},
#   'dt': 1511049600,
#   'id': 6089245,
#   'main': {'humidity': 76,
#    'pressure': 1024,
#    'temp': -7.61,
#    'temp_max': -7.61,
#    'temp_min': -7.61},
#   'name': 'Norman Wells',
#   'sys': {'country': 'CA',
#    'id': 3547,
#    'message': 0.1692,
#    'sunrise': 1511112173,
#    'sunset': 1511132519,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'light snow',
#     'icon': '13n',
#     'id': 600,
#     'main': 'Snow'}],
#   'wind': {'deg': 330, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 27.63, 'lon': 93.83},
#   'dt': 1511049600,
#   'id': 1252668,
#   'main': {'humidity': 100,
#    'pressure': 1013,
#    'temp': 62.6,
#    'temp_max': 62.6,
#    'temp_min': 62.6},
#   'name': 'Ziro',
#   'sys': {'country': 'IN',
#    'id': 7792,
#    'message': 0.0036,
#    'sunrise': 1511050113,
#    'sunset': 1511088676,
#    'type': 1},
#   'visibility': 4000,
#   'weather': [{'description': 'mist',
#     'icon': '50n',
#     'id': 701,
#     'main': 'Mist'}],
#   'wind': {'deg': 320, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -28.77, 'lon': 114.6},
#   'dt': 1511049600,
#   'id': 2070998,
#   'main': {'humidity': 56,
#    'pressure': 1014,
#    'temp': 69.8,
#    'temp_max': 69.8,
#    'temp_min': 69.8},
#   'name': 'Geraldton',
#   'sys': {'country': 'AU',
#    'id': 8186,
#    'message': 0.1679,
#    'sunrise': 1511039885,
#    'sunset': 1511088968,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 140, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': 28.45, 'lon': 117.97},
#   'dt': 1511052861,
#   'id': 1787858,
#   'main': {'grnd_level': 983.04,
#    'humidity': 84,
#    'pressure': 983.04,
#    'sea_level': 1039.97,
#    'temp': 42.87,
#    'temp_max': 42.87,
#    'temp_min': 42.87},
#   'name': 'Shangrao',
#   'sys': {'country': 'CN',
#    'message': 0.0102,
#    'sunrise': 1511044405,
#    'sunset': 1511082794},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 33.5046, 'speed': 3.71}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 19.73, 'lon': -155.09},
#   'dt': 1511049360,
#   'id': 5855927,
#   'main': {'humidity': 65,
#    'pressure': 1010,
#    'temp': 69.98,
#    'temp_max': 77,
#    'temp_min': 64.4},
#   'name': 'Hilo',
#   'sys': {'country': 'US',
#    'id': 818,
#    'message': 0.0039,
#    'sunrise': 1511109084,
#    'sunset': 1511149210,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -45.87, 'lon': 170.5},
#   'dt': 1511052768,
#   'id': 2191562,
#   'main': {'grnd_level': 995.6,
#    'humidity': 81,
#    'pressure': 995.6,
#    'sea_level': 1035.92,
#    'temp': 62.72,
#    'temp_max': 62.72,
#    'temp_min': 62.72},
#   'name': 'Dunedin',
#   'sys': {'country': 'NZ',
#    'message': 0.1676,
#    'sunrise': 1511023961,
#    'sunset': 1511078079},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 170.505, 'speed': 4.38}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': 65.85, 'lon': 74.49},
#   'dt': 1511052862,
#   'id': 1495626,
#   'main': {'grnd_level': 1021.13,
#    'humidity': 74,
#    'pressure': 1021.13,
#    'sea_level': 1029.11,
#    'temp': -2.72,
#    'temp_max': -2.72,
#    'temp_min': -2.72},
#   'name': 'Pangody',
#   'sys': {'country': 'RU',
#    'message': 0.0042,
#    'sunrise': 1511064144,
#    'sunset': 1511083897},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 83.0046, 'speed': 5.95}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 64.38, 'lon': -173.3},
#   'dt': 1511052863,
#   'id': 4031574,
#   'main': {'grnd_level': 999.25,
#    'humidity': 100,
#    'pressure': 999.25,
#    'sea_level': 1005.31,
#    'temp': 35.04,
#    'temp_max': 35.04,
#    'temp_min': 35.04},
#   'name': 'Provideniya',
#   'rain': {'3h': 4.32},
#   'sys': {'country': 'RU',
#    'message': 0.1733,
#    'sunrise': 1511122757,
#    'sunset': 1511144245},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10n',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 246.505, 'speed': 14.23}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': -39.2, 'lon': 173.88},
#   'dt': 1511052863,
#   'id': 2185763,
#   'main': {'grnd_level': 1019.27,
#    'humidity': 73,
#    'pressure': 1019.27,
#    'sea_level': 1028.95,
#    'temp': 65.06,
#    'temp_max': 65.06,
#    'temp_min': 65.06},
#   'name': 'Okato',
#   'sys': {'country': 'NZ',
#    'message': 0.1642,
#    'sunrise': 1511024294,
#    'sunset': 1511076113},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 147.505, 'speed': 18.48}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 71.92, 'lon': 114.08},
#   'dt': 1511052864,
#   'id': 2017155,
#   'main': {'grnd_level': 1023.97,
#    'humidity': 84,
#    'pressure': 1023.97,
#    'sea_level': 1036.56,
#    'temp': 3.09,
#    'temp_max': 3.09,
#    'temp_min': 3.09},
#   'name': 'Saskylakh',
# ...
#   'id': 6113406,
#   'main': {'humidity': 100,
#    'pressure': 1001,
#    'temp': 39.2,
#    'temp_max': 39.2,
#    'temp_min': 39.2},
#   'name': 'Prince Rupert',
#   'sys': {'country': 'CA',
#    'id': 3326,
#    'message': 0.246,
#    'sunrise': 1511108329,
#    'sunset': 1511138051,
#    'type': 1},
#   'visibility': 9656,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 85.5046, 'speed': 1.92}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1511049600,
#   'id': 4035715,
#   'main': {'humidity': 74,
#    'pressure': 1014,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#    'id': 8340,
#    'message': 0.3267,
#    'sunrise': 1511106537,
#    'sunset': 1511154033,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 62.46, 'lon': -114.35},
#   'dt': 1511049600,
#   'id': 6185377,
#   'main': {'humidity': 76,
#    'pressure': 1020,
#    'temp': -11.21,
#    'temp_max': -11.21,
#    'temp_min': -11.21},
#   'name': 'Yellowknife',
#   'sys': {'country': 'CA',
#    'id': 3558,
#    'message': 0.1637,
#    'sunrise': 1511107499,
#    'sunset': 1511131205,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 30, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 39.27, 'lon': 141.88},
#   'dt': 1511049600,
#   'id': 2112444,
#   'main': {'humidity': 69,
#    'pressure': 1009,
#    'temp': 37.4,
#    'temp_max': 37.4,
#    'temp_min': 37.4},
#   'name': 'Kamaishi',
#   'sys': {'country': 'JP',
#    'id': 7596,
#    'message': 0.1673,
#    'sunrise': 1511040003,
#    'sunset': 1511075711,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light shower snow',
#     'icon': '13d',
#     'id': 620,
#     'main': 'Snow'}],
#   'wind': {'deg': 280, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 10.7, 'lon': -12.25},
#   'dt': 1511052987,
#   'id': 2422383,
#   'main': {'grnd_level': 934.4,
#    'humidity': 71,
#    'pressure': 934.4,
#    'sea_level': 1023.8,
#    'temp': 66.32,
#    'temp_max': 66.32,
#    'temp_min': 66.32},
#   'name': 'Dalaba',
#   'sys': {'country': 'GN',
#    'message': 0.1659,
#    'sunrise': 1511073968,
#    'sunset': 1511115757},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 338.505, 'speed': 2.26}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -33.65, 'lon': 115.33},
#   'dt': 1511052885,
#   'id': 2075265,
#   'main': {'grnd_level': 1026.56,
#    'humidity': 100,
#    'pressure': 1026.56,
#    'sea_level': 1027.61,
#    'temp': 61.86,
#    'temp_max': 61.86,
#    'temp_min': 61.86},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#    'message': 0.1721,
#    'sunrise': 1511039116,
#    'sunset': 1511089392},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 186.505, 'speed': 4.5}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1511052855,
#   'id': 3366880,
#   'main': {'grnd_level': 988.71,
#    'humidity': 96,
#    'pressure': 988.71,
#    'sea_level': 1028.74,
#    'temp': 46.34,
#    'temp_max': 46.34,
#    'temp_min': 46.34},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#    'message': 0.168,
#    'sunrise': 1511062071,
#    'sunset': 1511112573},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 311.005, 'speed': 2.59}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.76},
#   'dt': 1511051760,
#   'id': 5106834,
#   'main': {'humidity': 81,
#    'pressure': 1000,
#    'temp': 42.06,
#    'temp_max': 42.8,
#    'temp_min': 41},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#    'id': 1292,
#    'message': 0.1676,
#    'sunrise': 1511092311,
#    'sunset': 1511126926,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 200, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 57.05, 'lon': -135.33},
#   'dt': 1511049360,
#   'id': 5557293,
#   'main': {'humidity': 74,
#    'pressure': 1003,
#    'temp': 32.09,
#    'temp_max': 37.4,
#    'temp_min': 28.4},
#   'name': 'Sitka',
#   'sys': {'country': 'US',
#    'id': 160,
#    'message': 0.2482,
#    'sunrise': 1511110352,
#    'sunset': 1511138431,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light snow',
#     'icon': '13d',
#     'id': 600,
#     'main': 'Snow'},
#    {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 320, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 68.05, 'lon': 39.51},
#   'dt': 1511052967,
#   'id': 556268,
#   'main': {'grnd_level': 987.74,
#    'humidity': 89,
#    'pressure': 987.74,
#    'sea_level': 1013.99,
#    'temp': 24.2,
#    'temp_max': 24.2,
#    'temp_min': 24.2},
#   'name': 'Ostrovnoy',
#   'sys': {'country': 'RU',
#    'message': 0.1675,
#    'sunrise': 1511074516,
#    'sunset': 1511090314},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 24.5046, 'speed': 5.39}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1511052834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.73,
#    'humidity': 100,
#    'pressure': 1029.73,
#    'sea_level': 1029.88,
#    'temp': 73.43,
#    'temp_max': 73.43,
#    'temp_min': 73.43},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.1676,
#    'sunrise': 1511100387,
#    'sunset': 1511148273},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 144.005, 'speed': 17.47}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 4.14, 'lon': 96.13},
#   'dt': 1511052989,
#   'id': 1214488,
#   'main': {'grnd_level': 1021.38,
#    'humidity': 100,
#    'pressure': 1021.38,
#    'sea_level': 1023.72,
#    'temp': 77.16,
#    'temp_max': 77.16,
#    'temp_min': 77.16},
#   'name': 'Meulaboh',
#   'sys': {'country': 'ID',
#    'message': 0.0074,
#    'sunrise': 1511047385,
#    'sunset': 1511090312},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 159.005, 'speed': 3.04}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 50.1, 'lon': -91.92},
#   'dt': 1511051340,
#   'id': 6148373,
#   'main': {'humidity': 78,
#    'pressure': 1010,
#    'temp': 14,
#    'temp_max': 14,
#    'temp_min': 14},
#   'name': 'Sioux Lookout',
#   'sys': {'country': 'CA',
#    'id': 3712,
#    'message': 0.1715,
#    'sunrise': 1511098068,
#    'sunset': 1511129881,
#    'type': 1},
#   'visibility': 3219,
#   'weather': [{'description': 'light shower snow',
#     'icon': '13n',
#     'id': 620,
#     'main': 'Snow'}],
#   'wind': {'deg': 300, 'gust': 9.3, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 35.03, 'lon': 10.91},
#   'dt': 1511049600,
#   'id': 2470260,
#   'main': {'humidity': 62,
#    'pressure': 1017,
#    'temp': 57.2,
#    'temp_max': 57.2,
#    'temp_min': 57.2},
#   'name': 'Jabinyanah',
#   'sys': {'country': 'TN',
#    'id': 6329,
#    'message': 0.166,
#    'sunrise': 1511070888,
#    'sunset': 1511107705,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 330, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 48.4, 'lon': -89.32},
#   'dt': 1511049600,
#   'id': 6166142,
#   'main': {'humidity': 79,
#    'pressure': 1009,
#    'temp': 23,
#    'temp_max': 23,
#    'temp_min': 23},
#   'name': 'Thunder Bay',
#   'sys': {'country': 'CA',
#    'id': 3717,
#    'message': 0.0048,
#    'sunrise': 1511097085,
#    'sunset': 1511129617,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'light snow',
#     'icon': '13n',
#     'id': 600,
#     'main': 'Snow'}],
#   'wind': {'deg': 310, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1511052849,
#   'id': 3874787,
#   'main': {'grnd_level': 1000.14,
#    'humidity': 100,
#    'pressure': 1000.14,
#    'sea_level': 1013.5,
#    'temp': 39.95,
#    'temp_max': 39.95,
#    'temp_min': 39.95},
#   'name': 'Punta Arenas',
#   'rain': {'3h': 0.17},
#   'sys': {'country': 'CL',
#    'message': 0.1679,
#    'sunrise': 1511080156,
#    'sunset': 1511137805},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 220.505, 'speed': 34.69}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 52.62, 'lon': 8.8},
#   'dt': 1511050800,
#   'id': 2952767,
#   'main': {'humidity': 93,
#    'pressure': 1011,
#    'temp': 38.75,
#    'temp_max': 39.2,
#    'temp_min': 37.4},
#   'name': 'Barenburg',
#   'sys': {'country': 'DE',
#    'id': 4951,
#    'message': 0.1654,
#    'sunrise': 1511074455,
#    'sunset': 1511105138,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.01, 'lon': 17.94},
#   'dt': 1511049600,
#   'id': 3361934,
#   'main': {'humidity': 82,
#    'pressure': 1015,
#    'temp': 55.4,
#    'temp_max': 55.4,
#    'temp_min': 55.4},
#   'name': 'Saldanha',
#   'sys': {'country': 'ZA',
#    'id': 6575,
#    'message': 0.1636,
#    'sunrise': 1511062564,
#    'sunset': 1511112698,
#    'type': 1},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -28.77, 'lon': 114.6},
#   'dt': 1511049600,
#   'id': 2070998,
#   'main': {'humidity': 56,
#    'pressure': 1014,
#    'temp': 69.8,
#    'temp_max': 69.8,
#    'temp_min': 69.8},
#   'name': 'Geraldton',
#   'sys': {'country': 'AU',
#    'id': 8186,
#    'message': 0.1679,
#    'sunrise': 1511039885,
#    'sunset': 1511088968,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 140, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.2, 'lon': -175.2},
#   'dt': 1511049600,
#   'id': 4032243,
#   'main': {'humidity': 88,
#    'pressure': 1011,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Vaini',
#   'sys': {'country': 'TO',
#    'id': 8323,
#    'message': 0.1737,
#    'sunrise': 1511110238,
#    'sunset': 1511157734,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 315.005, 'speed': 10.65}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1511052834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.73,
#    'humidity': 100,
#    'pressure': 1029.73,
#    'sea_level': 1029.88,
#    'temp': 73.43,
#    'temp_max': 73.43,
#    'temp_min': 73.43},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.1676,
#    'sunrise': 1511100387,
#    'sunset': 1511148273},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 144.005, 'speed': 17.47}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1511052847,
#   'id': 964432,
#   'main': {'grnd_level': 1020,
#    'humidity': 99,
#    'pressure': 1020,
#    'sea_level': 1028.99,
#    'temp': 58.49,
#    'temp_max': 58.49,
#    'temp_min': 58.49},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA',
#    'message': 0.1657,
#    'sunrise': 1511060342,
#    'sunset': 1511110624},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 326.005, 'speed': 5.84}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1511052887,
#   'id': 3831208,
#   'main': {'grnd_level': 1020.81,
#    'humidity': 100,
#    'pressure': 1020.81,
#    'sea_level': 1055.9,
#    'temp': -3.62,
#    'temp_max': -3.62,
#    'temp_min': -3.62},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL', 'message': 0.0067, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 96.5046, 'speed': 10.76}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 48.43, 'lon': -123.37},
#   'dt': 1511050500,
#   'id': 6174041,
#   'main': {'humidity': 70,
#    'pressure': 1020,
#    'temp': 48.81,
#    'temp_max': 51.8,
#    'temp_min': 46.4},
#   'name': 'Victoria',
#   'sys': {'country': 'CA',
#    'id': 3364,
#    'message': 0.1673,
#    'sunrise': 1511105271,
#    'sunset': 1511137778,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 21.39, 'lon': -158.15},
#   'dt': 1511049420,
#   'id': 5851349,
#   'main': {'humidity': 60,
#    'pressure': 1012,
#    'temp': 79.25,
#    'temp_max': 82.4,
#    'temp_min': 75.2},
#   'name': 'Nanakuli',
#   'sys': {'country': 'US',
#    'id': 840,
#    'message': 0.005,
#    'sunrise': 1511109980,
#    'sunset': 1511149783,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 360, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1511049600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 991,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.1655,
#    'sunrise': 1511079038,
#    'sunset': 1511137672,
#    'type': 1},
#   'visibility': 1200,
#   'weather': [{'description': 'heavy snow',
#     'icon': '13n',
#     'id': 602,
#     'main': 'Snow'}],
#   'wind': {'deg': 270, 'gust': 18, 'speed': 27.51}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1511052849,
#   'id': 3874787,
#   'main': {'grnd_level': 1000.14,
#    'humidity': 100,
#    'pressure': 1000.14,
#    'sea_level': 1013.5,
#    'temp': 39.95,
#    'temp_max': 39.95,
#    'temp_min': 39.95},
#   'name': 'Punta Arenas',
#   'rain': {'3h': 0.17},
#   'sys': {'country': 'CL',
#    'message': 0.1679,
#    'sunrise': 1511080156,
#    'sunset': 1511137805},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 220.505, 'speed': 34.69}}]

# %%
temp = weather_data[0]['main']['temp']

# %%
summary = ["name", "dt","sys.country","coord.lat", "coord.lon", "main.temp_max", "main.humidity", "clouds.all", "wind.speed"]
data = [response(*summary) for response in weather_data]
column_names = ["City", "Time", "Country", "Latitude", "Longitude", "Temperature", "Humidity", "Cloud Coverage", "Wind Speed"]
weather_data = pd.DataFrame(data, index = counter, columns=column_names)
print(weather_data)
# Out:
#                 City        Time Country  Latitude  Longitude  Temperature  \
# 1      Mar del Plata  1511049600      AR    -38.00     -57.56        48.20
# 2             Kodiak  1511049180      US     57.79    -152.41        37.40
# 3           Zhigansk  1511052831      RU     66.77     123.37       -17.30
# 4          Jamestown  1511051280      US     42.10     -79.24        51.80
# 5             Atuona  1511052831      PF     -9.80    -139.03        79.46
# 6           Grenfell  1511052832      AU    -33.90     148.17        66.95
# 7          Tazovskiy  1511052832      RU     67.47      78.70         0.26
# 8             Rudnik  1511052833      RU     69.75      61.65        10.92
# 9             Hobart  1511049600      AU    -42.88     147.33        77.00
# 10            Albany  1511051760      US     42.65     -73.76        42.80
# 11           Rikitea  1511052834      PF    -23.12    -134.97        73.43
# 12      Port Augusta  1511049600      AU    -32.50     137.77        73.40
# 13          Cherskiy  1511052835      RU     68.75     161.30         6.56
# 14        Port Blair  1511052835      IN     11.67      92.75        83.60
# 15           Mathura  1511052667      IN     27.50      77.68        59.34
# 16             Binga  1511052836      ZW    -17.62      27.34        72.44
# 17          Necochea  1511052808      AR    -38.55     -58.74        52.10
# 18             Bluff  1511052837      NZ    -46.60     168.33        55.79
# 19         Carnarvon  1511052837      AU    -24.87     113.63        68.93
# 20             Kapaa  1511051760      US     22.08    -159.32        71.60
# 21   Bambous Virieux  1511052839      MU    -20.34      57.76        74.15
# 22    Port Elizabeth  1511049600      ZA    -33.92      25.57        57.20
# 23             Pital  1511052839      CO      2.27     -75.80        68.30
# 24             Kapaa  1511051760      US     22.08    -159.32        71.60
# 25            Albany  1511051760      US     42.65     -73.76        42.80
# 26        Vikhorevka  1511049600      RU     56.12     101.16        21.20
# 27       Ferme-Neuve  1511052841      CA     46.70     -75.45        26.67
# 28          Monrovia  1511051400      LR      6.30     -10.80        77.00
# 29    Nisia Floresta  1511049600      BR     -6.09     -35.21        77.00
# 30        Vila Velha  1511049600      BR    -20.33     -40.29        77.00
# ..               ...         ...     ...       ...        ...          ...
# 428      Port Alfred  1511052847      ZA    -33.59      26.89        58.49
# 429        Hithadhoo  1511052846      MV     -0.60      73.08        82.79
# 430    Prince Rupert  1511049600      CA     54.32    -130.32        39.20
# 431           Avarua  1511049600      CK    -21.21    -159.78        80.60
# 432      Yellowknife  1511049600      CA     62.46    -114.35       -11.21
# 433         Kamaishi  1511049600      JP     39.27     141.88        37.40
# 434           Dalaba  1511052987      GN     10.70     -12.25        66.32
# 435        Busselton  1511052885      AU    -33.65     115.33        61.86
# 436          Ushuaia  1511049600      AR    -54.80     -68.30        33.80
# 437         Hermanus  1511052855      ZA    -34.42      19.23        46.34
# 438           Albany  1511051760      US     42.65     -73.76        42.80
# 439            Sitka  1511049360      US     57.05    -135.33        37.40
# 440        Ostrovnoy  1511052967      RU     68.05      39.51        24.20
# 441          Rikitea  1511052834      PF    -23.12    -134.97        73.43
# 442         Meulaboh  1511052989      ID      4.14      96.13        77.16
# 443    Sioux Lookout  1511051340      CA     50.10     -91.92        14.00
# 444       Jabinyanah  1511049600      TN     35.03      10.91        57.20
# 445      Thunder Bay  1511049600      CA     48.40     -89.32        23.00
# 446     Punta Arenas  1511052849      CL    -53.15     -70.92        39.95
# 447        Barenburg  1511050800      DE     52.62       8.80        39.20
# 448         Saldanha  1511049600      ZA    -33.01      17.94        55.40
# 449        Geraldton  1511049600      AU    -28.77     114.60        69.80
# 450            Vaini  1511049600      TO    -21.20    -175.20        80.60
# 451          Rikitea  1511052834      PF    -23.12    -134.97        73.43
# 452      Port Alfred  1511052847      ZA    -33.59      26.89        58.49
# 453          Qaanaaq  1511052887      GL     77.48     -69.36        -3.62
# 454         Victoria  1511050500      CA     48.43    -123.37        51.80
# 455         Nanakuli  1511049420      US     21.39    -158.15        82.40
# 456          Ushuaia  1511049600      AR    -54.80     -68.30        33.80
# 457     Punta Arenas  1511052849      CL    -53.15     -70.92        39.95
#
#      Humidity  Cloud Coverage  Wind Speed
# 1          81               0        3.36
# 2          59              20        8.05
# 3          76              36        5.95
# 4          93              90       12.75
# 5         100              64       11.32
# 6          91              20       11.77
# 7          75              80        7.40
# 8          91              36        8.08
# 9          33               0       10.29
# 10         81              90        9.17
# 11        100              56       17.47
# 12         56               0        8.05
# 13         79              88        9.64
# 14        100               0        2.26
# 15         76               0        9.98
# 16         87              48        6.96
# 17         75               0        7.18
# 18         93               8       13.56
# 19         99               0       11.65
# 20         94              90        6.93
# 21         92              92        6.62
# 22         82               0        6.93
# 23         81               8        2.37
# 24         94              90        6.93
# 25         81              90        9.17
# 26         92              90        2.24
# 27         89             100        4.61
# 28         94              75        7.74
# 29         78              20        5.82
# 30         78              20       11.41
# ..        ...             ...         ...
# 428        99               0        5.84
# 429       100              76       10.76
# 430       100              90        1.92
# 431        74              75       11.41
# 432        76              40        6.93
# 433        69              75        9.17
# 434        71              12        2.26
# 435       100              64        4.50
# 436       100              75       27.51
# 437        96               0        2.59
# 438        81              90        9.17
# 439        74              90        4.70
# 440        89              80        5.39
# 441       100              56       17.47
# 442       100              80        3.04
# 443        78              90       10.29
# 444        62              20        5.82
# 445        79              90        9.17
# 446       100              56       34.69
# 447        93              12       16.11
# 448        82               0        3.36
# 449        56               0       11.41
# 450        88              75       10.65
# 451       100              56       17.47
# 452        99               0        5.84
# 453       100              24       10.76
# 454        70              90        3.36
# 455        60               1       12.75
# 456       100              75       27.51
# 457       100              56       34.69
#
# [457 rows x 9 columns]

# %%
plt.scatter(weather_data["Latitude"], weather_data["Temperature"])
plt.xlabel("Latitude")   
plt.ylabel(("Temperature"))                         
plt.grid()
plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs. Latitude")
plt.grid()
plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloud Coverage"],)
plt.xlabel("Latitude")
plt.ylabel("Cloud Coverage")
plt.title("Cloud Coverage vs. Latitude")
plt.grid()
plt.show()

# %%
plt.scatter(weather_data["Wind Speed"], weather_data["Latitude"])
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Wind Speed vs. Latitude")
plt.show()
